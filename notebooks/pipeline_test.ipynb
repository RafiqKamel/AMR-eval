# %%
from general_parser.loaders import dataset_loader
loader = dataset_loader("../AMR/LP/full.txt")
# Out:
# [amr] Loading AMRs from file: ../AMR/LP/full.txt

# %%
from general_parser.models import transition_AMR_parser
parser = transition_AMR_parser(model_name='AMR3-structbart-L')
# Out:
# load from cache /Users/rafiqmazen/.cache/torch/DATA/AMR3.0/models/amr3.0-structured-bart-large-neur-al/seed42/checkpoint_wiki.smatch_top5-avg.pt
# | [en] dictionary: 46088 types
# | [actions_nopos] dictionary: 16544 types
# ----------loading pretrained bart.large model ----------
# Using cache found in /Users/rafiqmazen/.cache/torch/hub/pytorch_fairseq_main
# 2024-01-19 01:55:01 | INFO | fairseq.file_utils | loading archive file http://dl.fbaipublicfiles.com/fairseq/models/bart.large.tar.gz from cache at /Users/rafiqmazen/.cache/torch/pytorch_fairseq/40858f8de84f479771b2807266d806749e9ad0f8cb547921c35a76ae9c3ed0f6.099ef973524a5edb31b1211569b67bcc2863bc6d00781b79bac752acf8e48991
# 2024-01-19 01:55:03 | INFO | fairseq.tasks.denoising | dictionary: 50264 types
# ---------- task bart rewind: loading pretrained bart.large model ----------
# Using cache found in /Users/rafiqmazen/.cache/torch/hub/pytorch_fairseq_main
# 2024-01-19 01:55:15 | INFO | fairseq.file_utils | loading archive file http://dl.fbaipublicfiles.com/fairseq/models/bart.large.tar.gz from cache at /Users/rafiqmazen/.cache/torch/pytorch_fairseq/40858f8de84f479771b2807266d806749e9ad0f8cb547921c35a76ae9c3ed0f6.099ef973524a5edb31b1211569b67bcc2863bc6d00781b79bac752acf8e48991
# 2024-01-19 01:55:16 | INFO | fairseq.tasks.denoising | dictionary: 50264 types
# using CPU for models
# pretrained_embed:  bart.large
# Using cache found in /Users/rafiqmazen/.cache/torch/hub/pytorch_fairseq_main
# 2024-01-19 01:55:37 | INFO | fairseq.file_utils | loading archive file http://dl.fbaipublicfiles.com/fairseq/models/bart.large.tar.gz from cache at /Users/rafiqmazen/.cache/torch/pytorch_fairseq/40858f8de84f479771b2807266d806749e9ad0f8cb547921c35a76ae9c3ed0f6.099ef973524a5edb31b1211569b67bcc2863bc6d00781b79bac752acf8e48991
# 2024-01-19 01:55:39 | INFO | fairseq.tasks.denoising | dictionary: 50264 types
# Using bart.large extraction in cpu (slow, wont OOM)
# Finished loading models
# self.machine_config:  /Users/rafiqmazen/.cache/torch/DATA/AMR3.0/models/amr3.0-structured-bart-large-neur-al/seed42/machine_config.json

# %%
amr_pred = []
for sent in loader.sentences:
    amr_pred.append(parser.parse_amr(sent,plot=False))
# Out:
# Running on batch size: 1
# 1
# decoding: 100%|██████████| 1/1 [00:00<00:00,  1.55it/s]
# Running on batch size: 1
# 1
# decoding: 100%|██████████| 1/1 [00:02<00:00,  2.34s/it]
# Running on batch size: 1
# 1
# decoding: 100%|██████████| 1/1 [00:01<00:00,  1.06s/it]
# Running on batch size: 1
# 1
# decoding: 100%|██████████| 1/1 [00:00<00:00,  1.42it/s]
# Running on batch size: 1
# 1
# decoding: 100%|██████████| 1/1 [00:01<00:00,  1.78s/it]
# Running on batch size: 1
# 1
# decoding: 100%|██████████| 1/1 [00:01<00:00,  1.95s/it]
# Running on batch size: 1
# 1
# decoding:   0%|          | 0/1 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 3
#       1 amr_pred = []
#       2 for sent in loader.sentences:
# ----> 3     amr_pred.append(parser.parse_amr(sent,plot=False))
#
# File ~/AMR-eval/notebooks/general_parser/models/_ibm_transition_parser.py:13, in transition_AMR_parser.parse_amr(self, text, plot)
#      11 def parse_amr(self, text: str, plot: bool = True):
#      12     tokens, _ = self.parser.tokenize(text)
# ---> 13     annotations, machines = self.parser.parse_sentence(tokens)
#      14     amr = machines.get_amr()
#      15     if plot:
#
# File ~/AMR-eval/transition-amr-parser/src/transition_amr_parser/parse.py:993, in AMRParser.parse_sentence(self, tokens, **kwargs)
#     992 def parse_sentence(self, tokens, **kwargs):
# --> 993     annotations, decoding_data = self.parse_sentences([tokens], **kwargs)
#     994     return annotations[0], decoding_data[0]
#
# File ~/AMR-eval/transition-amr-parser/src/transition_amr_parser/parse.py:1045, in AMRParser.parse_sentences(self, batch, batch_size, roberta_batch_size, gold_amrs, force_actions, beam, jamr, no_isi, unicode_normalize)
#    1042     continue
#    1044 # parse for this data batch
# -> 1045 predictions = self.parse_batch(sample, to_amr=self.to_amr)
#    1047 # collect all annotations
#    1048 if not self.to_amr:
#
# File ~/AMR-eval/transition-amr-parser/src/transition_amr_parser/parse.py:931, in AMRParser.parse_batch(self, sample, to_amr)
#     928 def parse_batch(self, sample, to_amr=True):
#     929     # TODO: pass arbitrary machines in generator to enable inspector and
#     930     # other
# --> 931     hypos = self.task.inference_step(
#     932         self.generator, self.models, sample, self.args, prefix_tokens=None
#     933     )
#     935     predictions = []
#     936     for i, sample_id in enumerate(sample['id'].tolist()):
#
# File ~/AMR-eval/transition-amr-parser/src/fairseq_ext/tasks/amr_action_pointer_bart.py:548, in AMRActionPointerBARTParsingTask.inference_step(self, generator, models, sample, args, prefix_tokens)
#     546 def inference_step(self, generator, models, sample, args, prefix_tokens=None):
#     547     with torch.no_grad():
# --> 548         return generator.generate(models, sample, prefix_tokens=prefix_tokens,
#     549                                   run_amr_sm=args.run_amr_sm,
#     550                                   modify_arcact_score=args.modify_arcact_score,
#     551                                   use_pred_rules=args.use_pred_rules)
#
# File ~/anaconda3/envs/spring2/lib/python3.9/site-packages/torch/autograd/grad_mode.py:27, in _DecoratorContextManager.__call__.<locals>.decorate_context(*args, **kwargs)
#      24 @functools.wraps(func)
#      25 def decorate_context(*args, **kwargs):
#      26     with self.clone():
# ---> 27         return func(*args, **kwargs)
#
# File ~/AMR-eval/transition-amr-parser/src/fairseq_ext/sequence_generator.py:603, in SequenceGenerator.generate(self, models, sample, prefix_tokens, bos_token, run_amr_sm, modify_arcact_score, use_pred_rules, **kwargs)
#     600         pred_ids_allowed = set(self.tgt_dict.index(f'PRED({sym})') for sym in pred_allowed)
#     601         vocab_ids_allowed = vocab_ids_allowed.union(pred_ids_allowed)
# --> 603     allowed_mask[i, list(vocab_ids_allowed)] = 1
#     605     tok_cursors[i] = sm.tok_cursor
#     607 # NOTE blocking <unk> separately is needed when `use_pred_rules` is True, as the possible predicates
#     608 #      generated by training oracle are not fully contained in the dictionary
#
# KeyboardInterrupt:

# %%
amr_pred = parser.parse_amr_batches(loader.sentences)
# Out:
# Running on batch size: 256
# 1562
# decoding:   0%|          | 0/7 [00:00<?, ?it/s]/Users/rafiqmazen/AMR-eval/transition-amr-parser/src/fairseq_ext/sequence_generator.py:1020: UserWarning: An output with one or more elements was resized since it had shape [256, 2], which does not match the required output shape [255, 2]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.add(
# /Users/rafiqmazen/AMR-eval/transition-amr-parser/src/fairseq_ext/sequence_generator.py:1031: UserWarning: An output with one or more elements was resized since it had shape [256, 1], which does not match the required output shape [255, 1]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.topk(
# /Users/rafiqmazen/AMR-eval/transition-amr-parser/src/fairseq_ext/sequence_generator.py:1061: UserWarning: An output with one or more elements was resized since it had shape [256, 1], which does not match the required output shape [255, 1]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.gather(
# /Users/rafiqmazen/AMR-eval/transition-amr-parser/src/fairseq_ext/sequence_generator.py:928: UserWarning: An output with one or more elements was resized since it had shape [1], which does not match the required output shape [2]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.masked_select(
# /Users/rafiqmazen/AMR-eval/transition-amr-parser/src/fairseq_ext/sequence_generator.py:934: UserWarning: An output with one or more elements was resized since it had shape [1], which does not match the required output shape [2]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.masked_select(
# /Users/rafiqmazen/AMR-eval/transition-amr-parser/src/fairseq_ext/sequence_generator.py:1020: UserWarning: An output with one or more elements was resized since it had shape [255, 2], which does not match the required output shape [253, 2]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.add(
# /Users/rafiqmazen/AMR-eval/transition-amr-parser/src/fairseq_ext/sequence_generator.py:1031: UserWarning: An output with one or more elements was resized since it had shape [255, 1], which does not match the required output shape [253, 1]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.topk(
# /Users/rafiqmazen/AMR-eval/transition-amr-parser/src/fairseq_ext/sequence_generator.py:1061: UserWarning: An output with one or more elements was resized since it had shape [255, 1], which does not match the required output shape [253, 1]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.gather(
# /Users/rafiqmazen/AMR-eval/transition-amr-parser/src/fairseq_ext/sequence_generator.py:928: UserWarning: An output with one or more elements was resized since it had shape [2], which does not match the required output shape [10]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.masked_select(
# /Users/rafiqmazen/AMR-eval/transition-amr-parser/src/fairseq_ext/sequence_generator.py:934: UserWarning: An output with one or more elements was resized since it had shape [2], which does not match the required output shape [10]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.masked_select(
# /Users/rafiqmazen/AMR-eval/transition-amr-parser/src/fairseq_ext/sequence_generator.py:1020: UserWarning: An output with one or more elements was resized since it had shape [253, 2], which does not match the required output shape [243, 2]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.add(
# /Users/rafiqmazen/AMR-eval/transition-amr-parser/src/fairseq_ext/sequence_generator.py:1031: UserWarning: An output with one or more elements was resized since it had shape [253, 1], which does not match the required output shape [243, 1]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.topk(
# /Users/rafiqmazen/AMR-eval/transition-amr-parser/src/fairseq_ext/sequence_generator.py:1061: UserWarning: An output with one or more elements was resized since it had shape [253, 1], which does not match the required output shape [243, 1]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.gather(
# /Users/rafiqmazen/AMR-eval/transition-amr-parser/src/fairseq_ext/sequence_generator.py:928: UserWarning: An output with one or more elements was resized since it had shape [10], which does not match the required output shape [2]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.masked_select(
# /Users/rafiqmazen/AMR-eval/transition-amr-parser/src/fairseq_ext/sequence_generator.py:934: UserWarning: An output with one or more elements was resized since it had shape [10], which does not match the required output shape [2]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.masked_select(
# /Users/rafiqmazen/AMR-eval/transition-amr-parser/src/fairseq_ext/sequence_generator.py:1020: UserWarning: An output with one or more elements was resized since it had shape [243, 2], which does not match the required output shape [241, 2]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.add(
# /Users/rafiqmazen/AMR-eval/transition-amr-parser/src/fairseq_ext/sequence_generator.py:1031: UserWarning: An output with one or more elements was resized since it had shape [243, 1], which does not match the required output shape [241, 1]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.topk(
# /Users/rafiqmazen/AMR-eval/transition-amr-parser/src/fairseq_ext/sequence_generator.py:1061: UserWarning: An output with one or more elements was resized since it had shape [243, 1], which does not match the required output shape [241, 1]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.gather(
# /Users/rafiqmazen/AMR-eval/transition-amr-parser/src/fairseq_ext/sequence_generator.py:928: UserWarning: An output with one or more elements was resized since it had shape [2], which does not match the required output shape [5]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.masked_select(
# /Users/rafiqmazen/AMR-eval/transition-amr-parser/src/fairseq_ext/sequence_generator.py:934: UserWarning: An output with one or more elements was resized since it had shape [2], which does not match the required output shape [5]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.masked_select(
# /Users/rafiqmazen/AMR-eval/transition-amr-parser/src/fairseq_ext/sequence_generator.py:1020: UserWarning: An output with one or more elements was resized since it had shape [241, 2], which does not match the required output shape [236, 2]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.add(
# /Users/rafiqmazen/AMR-eval/transition-amr-parser/src/fairseq_ext/sequence_generator.py:1031: UserWarning: An output with one or more elements was resized since it had shape [241, 1], which does not match the required output shape [236, 1]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.topk(
# /Users/rafiqmazen/AMR-eval/transition-amr-parser/src/fairseq_ext/sequence_generator.py:1061: UserWarning: An output with one or more elements was resized since it had shape [241, 1], which does not match the required output shape [236, 1]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.gather(
# /Users/rafiqmazen/AMR-eval/transition-amr-parser/src/fairseq_ext/sequence_generator.py:928: UserWarning: An output with one or more elements was resized since it had shape [5], which does not match the required output shape [0]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.masked_select(
# /Users/rafiqmazen/AMR-eval/transition-amr-parser/src/fairseq_ext/sequence_generator.py:934: UserWarning: An output with one or more elements was resized since it had shape [5], which does not match the required output shape [3]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.masked_select(
# /Users/rafiqmazen/AMR-eval/transition-amr-parser/src/fairseq_ext/sequence_generator.py:1020: UserWarning: An output with one or more elements was resized since it had shape [236, 2], which does not match the required output shape [233, 2]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.add(
# /Users/rafiqmazen/AMR-eval/transition-amr-parser/src/fairseq_ext/sequence_generator.py:1031: UserWarning: An output with one or more elements was resized since it had shape [236, 1], which does not match the required output shape [233, 1]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.topk(
# /Users/rafiqmazen/AMR-eval/transition-amr-parser/src/fairseq_ext/sequence_generator.py:1061: UserWarning: An output with one or more elements was resized since it had shape [236, 1], which does not match the required output shape [233, 1]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.gather(
# /Users/rafiqmazen/AMR-eval/transition-amr-parser/src/fairseq_ext/sequence_generator.py:928: UserWarning: An output with one or more elements was resized since it had shape [3], which does not match the required output shape [7]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.masked_select(
# /Users/rafiqmazen/AMR-eval/transition-amr-parser/src/fairseq_ext/sequence_generator.py:934: UserWarning: An output with one or more elements was resized since it had shape [3], which does not match the required output shape [7]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.masked_select(
# /Users/rafiqmazen/AMR-eval/transition-amr-parser/src/fairseq_ext/sequence_generator.py:1020: UserWarning: An output with one or more elements was resized since it had shape [233, 2], which does not match the required output shape [226, 2]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.add(
# /Users/rafiqmazen/AMR-eval/transition-amr-parser/src/fairseq_ext/sequence_generator.py:1031: UserWarning: An output with one or more elements was resized since it had shape [233, 1], which does not match the required output shape [226, 1]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.topk(
# /Users/rafiqmazen/AMR-eval/transition-amr-parser/src/fairseq_ext/sequence_generator.py:1061: UserWarning: An output with one or more elements was resized since it had shape [233, 1], which does not match the required output shape [226, 1]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.gather(
# /Users/rafiqmazen/AMR-eval/transition-amr-parser/src/fairseq_ext/sequence_generator.py:928: UserWarning: An output with one or more elements was resized since it had shape [7], which does not match the required output shape [4]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.masked_select(
# /Users/rafiqmazen/AMR-eval/transition-amr-parser/src/fairseq_ext/sequence_generator.py:934: UserWarning: An output with one or more elements was resized since it had shape [7], which does not match the required output shape [4]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.masked_select(
# /Users/rafiqmazen/AMR-eval/transition-amr-parser/src/fairseq_ext/sequence_generator.py:1020: UserWarning: An output with one or more elements was resized since it had shape [226, 2], which does not match the required output shape [222, 2]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.add(
# /Users/rafiqmazen/AMR-eval/transition-amr-parser/src/fairseq_ext/sequence_generator.py:1031: UserWarning: An output with one or more elements was resized since it had shape [226, 1], which does not match the required output shape [222, 1]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.topk(
# /Users/rafiqmazen/AMR-eval/transition-amr-parser/src/fairseq_ext/sequence_generator.py:1061: UserWarning: An output with one or more elements was resized since it had shape [226, 1], which does not match the required output shape [222, 1]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.gather(
# /Users/rafiqmazen/AMR-eval/transition-amr-parser/src/fairseq_ext/sequence_generator.py:928: UserWarning: An output with one or more elements was resized since it had shape [4], which does not match the required output shape [3]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.masked_select(
# /Users/rafiqmazen/AMR-eval/transition-amr-parser/src/fairseq_ext/sequence_generator.py:934: UserWarning: An output with one or more elements was resized since it had shape [4], which does not match the required output shape [3]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.masked_select(
# /Users/rafiqmazen/AMR-eval/transition-amr-parser/src/fairseq_ext/sequence_generator.py:1020: UserWarning: An output with one or more elements was resized since it had shape [222, 2], which does not match the required output shape [219, 2]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.add(
# /Users/rafiqmazen/AMR-eval/transition-amr-parser/src/fairseq_ext/sequence_generator.py:1031: UserWarning: An output with one or more elements was resized since it had shape [222, 1], which does not match the required output shape [219, 1]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.topk(
# /Users/rafiqmazen/AMR-eval/transition-amr-parser/src/fairseq_ext/sequence_generator.py:1061: UserWarning: An output with one or more elements was resized since it had shape [222, 1], which does not match the required output shape [219, 1]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.gather(
# /Users/rafiqmazen/AMR-eval/transition-amr-parser/src/fairseq_ext/sequence_generator.py:928: UserWarning: An output with one or more elements was resized since it had shape [3], which does not match the required output shape [8]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.masked_select(
# /Users/rafiqmazen/AMR-eval/transition-amr-parser/src/fairseq_ext/sequence_generator.py:934: UserWarning: An output with one or more elements was resized since it had shape [3], which does not match the required output shape [8]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.masked_select(
# /Users/rafiqmazen/AMR-eval/transition-amr-parser/src/fairseq_ext/sequence_generator.py:1020: UserWarning: An output with one or more elements was resized since it had shape [219, 2], which does not match the required output shape [211, 2]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.add(
# /Users/rafiqmazen/AMR-eval/transition-amr-parser/src/fairseq_ext/sequence_generator.py:1031: UserWarning: An output with one or more elements was resized since it had shape [219, 1], which does not match the required output shape [211, 1]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.topk(
# /Users/rafiqmazen/AMR-eval/transition-amr-parser/src/fairseq_ext/sequence_generator.py:1061: UserWarning: An output with one or more elements was resized since it had shape [219, 1], which does not match the required output shape [211, 1]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.gather(
# /Users/rafiqmazen/AMR-eval/transition-amr-parser/src/fairseq_ext/sequence_generator.py:928: UserWarning: An output with one or more elements was resized since it had shape [8], which does not match the required output shape [5]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.masked_select(
# /Users/rafiqmazen/AMR-eval/transition-amr-parser/src/fairseq_ext/sequence_generator.py:934: UserWarning: An output with one or more elements was resized since it had shape [8], which does not match the required output shape [5]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.masked_select(
# /Users/rafiqmazen/AMR-eval/transition-amr-parser/src/fairseq_ext/sequence_generator.py:1020: UserWarning: An output with one or more elements was resized since it had shape [211, 2], which does not match the required output shape [206, 2]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.add(
# /Users/rafiqmazen/AMR-eval/transition-amr-parser/src/fairseq_ext/sequence_generator.py:1031: UserWarning: An output with one or more elements was resized since it had shape [211, 1], which does not match the required output shape [206, 1]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.topk(
# /Users/rafiqmazen/AMR-eval/transition-amr-parser/src/fairseq_ext/sequence_generator.py:1061: UserWarning: An output with one or more elements was resized since it had shape [211, 1], which does not match the required output shape [206, 1]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.gather(
# /Users/rafiqmazen/AMR-eval/transition-amr-parser/src/fairseq_ext/sequence_generator.py:928: UserWarning: An output with one or more elements was resized since it had shape [5], which does not match the required output shape [7]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.masked_select(
# /Users/rafiqmazen/AMR-eval/transition-amr-parser/src/fairseq_ext/sequence_generator.py:934: UserWarning: An output with one or more elements was resized since it had shape [5], which does not match the required output shape [7]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.masked_select(
# /Users/rafiqmazen/AMR-eval/transition-amr-parser/src/fairseq_ext/sequence_generator.py:1020: UserWarning: An output with one or more elements was resized since it had shape [206, 2], which does not match the required output shape [199, 2]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.add(
# /Users/rafiqmazen/AMR-eval/transition-amr-parser/src/fairseq_ext/sequence_generator.py:1031: UserWarning: An output with one or more elements was resized since it had shape [206, 1], which does not match the required output shape [199, 1]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.topk(
# /Users/rafiqmazen/AMR-eval/transition-amr-parser/src/fairseq_ext/sequence_generator.py:1061: UserWarning: An output with one or more elements was resized since it had shape [206, 1], which does not match the required output shape [199, 1]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.gather(
# /Users/rafiqmazen/AMR-eval/transition-amr-parser/src/fairseq_ext/sequence_generator.py:928: UserWarning: An output with one or more elements was resized since it had shape [7], which does not match the required output shape [3]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.masked_select(
# /Users/rafiqmazen/AMR-eval/transition-amr-parser/src/fairseq_ext/sequence_generator.py:934: UserWarning: An output with one or more elements was resized since it had shape [7], which does not match the required output shape [3]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.masked_select(
# /Users/rafiqmazen/AMR-eval/transition-amr-parser/src/fairseq_ext/sequence_generator.py:1020: UserWarning: An output with one or more elements was resized since it had shape [199, 2], which does not match the required output shape [196, 2]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.add(
# /Users/rafiqmazen/AMR-eval/transition-amr-parser/src/fairseq_ext/sequence_generator.py:1031: UserWarning: An output with one or more elements was resized since it had shape [199, 1], which does not match the required output shape [196, 1]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.topk(
# /Users/rafiqmazen/AMR-eval/transition-amr-parser/src/fairseq_ext/sequence_generator.py:1061: UserWarning: An output with one or more elements was resized since it had shape [199, 1], which does not match the required output shape [196, 1]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.gather(
# /Users/rafiqmazen/AMR-eval/transition-amr-parser/src/fairseq_ext/sequence_generator.py:1020: UserWarning: An output with one or more elements was resized since it had shape [196, 2], which does not match the required output shape [189, 2]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.add(
# /Users/rafiqmazen/AMR-eval/transition-amr-parser/src/fairseq_ext/sequence_generator.py:1031: UserWarning: An output with one or more elements was resized since it had shape [196, 1], which does not match the required output shape [189, 1]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.topk(
# /Users/rafiqmazen/AMR-eval/transition-amr-parser/src/fairseq_ext/sequence_generator.py:1061: UserWarning: An output with one or more elements was resized since it had shape [196, 1], which does not match the required output shape [189, 1]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.gather(
# /Users/rafiqmazen/AMR-eval/transition-amr-parser/src/fairseq_ext/sequence_generator.py:928: UserWarning: An output with one or more elements was resized since it had shape [7], which does not match the required output shape [6]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.masked_select(
# /Users/rafiqmazen/AMR-eval/transition-amr-parser/src/fairseq_ext/sequence_generator.py:934: UserWarning: An output with one or more elements was resized since it had shape [7], which does not match the required output shape [6]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.masked_select(
# /Users/rafiqmazen/AMR-eval/transition-amr-parser/src/fairseq_ext/sequence_generator.py:1020: UserWarning: An output with one or more elements was resized since it had shape [189, 2], which does not match the required output shape [183, 2]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.add(
# /Users/rafiqmazen/AMR-eval/transition-amr-parser/src/fairseq_ext/sequence_generator.py:1031: UserWarning: An output with one or more elements was resized since it had shape [189, 1], which does not match the required output shape [183, 1]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.topk(
# /Users/rafiqmazen/AMR-eval/transition-amr-parser/src/fairseq_ext/sequence_generator.py:1061: UserWarning: An output with one or more elements was resized since it had shape [189, 1], which does not match the required output shape [183, 1]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.gather(
# /Users/rafiqmazen/AMR-eval/transition-amr-parser/src/fairseq_ext/sequence_generator.py:928: UserWarning: An output with one or more elements was resized since it had shape [6], which does not match the required output shape [5]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.masked_select(
# /Users/rafiqmazen/AMR-eval/transition-amr-parser/src/fairseq_ext/sequence_generator.py:934: UserWarning: An output with one or more elements was resized since it had shape [6], which does not match the required output shape [5]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.masked_select(
# /Users/rafiqmazen/AMR-eval/transition-amr-parser/src/fairseq_ext/sequence_generator.py:1020: UserWarning: An output with one or more elements was resized since it had shape [183, 2], which does not match the required output shape [178, 2]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.add(
# /Users/rafiqmazen/AMR-eval/transition-amr-parser/src/fairseq_ext/sequence_generator.py:1031: UserWarning: An output with one or more elements was resized since it had shape [183, 1], which does not match the required output shape [178, 1]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.topk(
# /Users/rafiqmazen/AMR-eval/transition-amr-parser/src/fairseq_ext/sequence_generator.py:1061: UserWarning: An output with one or more elements was resized since it had shape [183, 1], which does not match the required output shape [178, 1]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.gather(
# /Users/rafiqmazen/AMR-eval/transition-amr-parser/src/fairseq_ext/sequence_generator.py:928: UserWarning: An output with one or more elements was resized since it had shape [5], which does not match the required output shape [9]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.masked_select(
# /Users/rafiqmazen/AMR-eval/transition-amr-parser/src/fairseq_ext/sequence_generator.py:934: UserWarning: An output with one or more elements was resized since it had shape [5], which does not match the required output shape [9]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.masked_select(
# /Users/rafiqmazen/AMR-eval/transition-amr-parser/src/fairseq_ext/sequence_generator.py:1020: UserWarning: An output with one or more elements was resized since it had shape [178, 2], which does not match the required output shape [169, 2]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.add(
# /Users/rafiqmazen/AMR-eval/transition-amr-parser/src/fairseq_ext/sequence_generator.py:1031: UserWarning: An output with one or more elements was resized since it had shape [178, 1], which does not match the required output shape [169, 1]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.topk(
# /Users/rafiqmazen/AMR-eval/transition-amr-parser/src/fairseq_ext/sequence_generator.py:1061: UserWarning: An output with one or more elements was resized since it had shape [178, 1], which does not match the required output shape [169, 1]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.gather(
# /Users/rafiqmazen/AMR-eval/transition-amr-parser/src/fairseq_ext/sequence_generator.py:1020: UserWarning: An output with one or more elements was resized since it had shape [169, 2], which does not match the required output shape [160, 2]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.add(
# ...
#   torch.topk(
# /Users/rafiqmazen/AMR-eval/transition-amr-parser/src/fairseq_ext/sequence_generator.py:1061: UserWarning: An output with one or more elements was resized since it had shape [61, 1], which does not match the required output shape [56, 1]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.gather(
# /Users/rafiqmazen/AMR-eval/transition-amr-parser/src/fairseq_ext/sequence_generator.py:1020: UserWarning: An output with one or more elements was resized since it had shape [56, 2], which does not match the required output shape [50, 2]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.add(
# /Users/rafiqmazen/AMR-eval/transition-amr-parser/src/fairseq_ext/sequence_generator.py:1031: UserWarning: An output with one or more elements was resized since it had shape [56, 1], which does not match the required output shape [50, 1]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.topk(
# /Users/rafiqmazen/AMR-eval/transition-amr-parser/src/fairseq_ext/sequence_generator.py:1061: UserWarning: An output with one or more elements was resized since it had shape [56, 1], which does not match the required output shape [50, 1]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.gather(
# /Users/rafiqmazen/AMR-eval/transition-amr-parser/src/fairseq_ext/sequence_generator.py:1020: UserWarning: An output with one or more elements was resized since it had shape [50, 2], which does not match the required output shape [47, 2]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.add(
# /Users/rafiqmazen/AMR-eval/transition-amr-parser/src/fairseq_ext/sequence_generator.py:1031: UserWarning: An output with one or more elements was resized since it had shape [50, 1], which does not match the required output shape [47, 1]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.topk(
# /Users/rafiqmazen/AMR-eval/transition-amr-parser/src/fairseq_ext/sequence_generator.py:1061: UserWarning: An output with one or more elements was resized since it had shape [50, 1], which does not match the required output shape [47, 1]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.gather(
# /Users/rafiqmazen/AMR-eval/transition-amr-parser/src/fairseq_ext/sequence_generator.py:1020: UserWarning: An output with one or more elements was resized since it had shape [47, 2], which does not match the required output shape [44, 2]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.add(
# /Users/rafiqmazen/AMR-eval/transition-amr-parser/src/fairseq_ext/sequence_generator.py:1031: UserWarning: An output with one or more elements was resized since it had shape [47, 1], which does not match the required output shape [44, 1]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.topk(
# /Users/rafiqmazen/AMR-eval/transition-amr-parser/src/fairseq_ext/sequence_generator.py:1061: UserWarning: An output with one or more elements was resized since it had shape [47, 1], which does not match the required output shape [44, 1]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.gather(
# /Users/rafiqmazen/AMR-eval/transition-amr-parser/src/fairseq_ext/sequence_generator.py:1020: UserWarning: An output with one or more elements was resized since it had shape [44, 2], which does not match the required output shape [43, 2]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.add(
# /Users/rafiqmazen/AMR-eval/transition-amr-parser/src/fairseq_ext/sequence_generator.py:1031: UserWarning: An output with one or more elements was resized since it had shape [44, 1], which does not match the required output shape [43, 1]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.topk(
# /Users/rafiqmazen/AMR-eval/transition-amr-parser/src/fairseq_ext/sequence_generator.py:1061: UserWarning: An output with one or more elements was resized since it had shape [44, 1], which does not match the required output shape [43, 1]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.gather(
# /Users/rafiqmazen/AMR-eval/transition-amr-parser/src/fairseq_ext/sequence_generator.py:928: UserWarning: An output with one or more elements was resized since it had shape [1], which does not match the required output shape [5]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.masked_select(
# /Users/rafiqmazen/AMR-eval/transition-amr-parser/src/fairseq_ext/sequence_generator.py:934: UserWarning: An output with one or more elements was resized since it had shape [1], which does not match the required output shape [5]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.masked_select(
# /Users/rafiqmazen/AMR-eval/transition-amr-parser/src/fairseq_ext/sequence_generator.py:1020: UserWarning: An output with one or more elements was resized since it had shape [43, 2], which does not match the required output shape [38, 2]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.add(
# /Users/rafiqmazen/AMR-eval/transition-amr-parser/src/fairseq_ext/sequence_generator.py:1031: UserWarning: An output with one or more elements was resized since it had shape [43, 1], which does not match the required output shape [38, 1]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.topk(
# /Users/rafiqmazen/AMR-eval/transition-amr-parser/src/fairseq_ext/sequence_generator.py:1061: UserWarning: An output with one or more elements was resized since it had shape [43, 1], which does not match the required output shape [38, 1]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.gather(
# /Users/rafiqmazen/AMR-eval/transition-amr-parser/src/fairseq_ext/sequence_generator.py:1020: UserWarning: An output with one or more elements was resized since it had shape [38, 2], which does not match the required output shape [34, 2]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.add(
# /Users/rafiqmazen/AMR-eval/transition-amr-parser/src/fairseq_ext/sequence_generator.py:1031: UserWarning: An output with one or more elements was resized since it had shape [38, 1], which does not match the required output shape [34, 1]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.topk(
# /Users/rafiqmazen/AMR-eval/transition-amr-parser/src/fairseq_ext/sequence_generator.py:1061: UserWarning: An output with one or more elements was resized since it had shape [38, 1], which does not match the required output shape [34, 1]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.gather(
# /Users/rafiqmazen/AMR-eval/transition-amr-parser/src/fairseq_ext/sequence_generator.py:1020: UserWarning: An output with one or more elements was resized since it had shape [33, 2], which does not match the required output shape [32, 2]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.add(
# /Users/rafiqmazen/AMR-eval/transition-amr-parser/src/fairseq_ext/sequence_generator.py:1031: UserWarning: An output with one or more elements was resized since it had shape [33, 1], which does not match the required output shape [32, 1]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.topk(
# /Users/rafiqmazen/AMR-eval/transition-amr-parser/src/fairseq_ext/sequence_generator.py:1061: UserWarning: An output with one or more elements was resized since it had shape [33, 1], which does not match the required output shape [32, 1]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.gather(
# /Users/rafiqmazen/AMR-eval/transition-amr-parser/src/fairseq_ext/sequence_generator.py:1020: UserWarning: An output with one or more elements was resized since it had shape [32, 2], which does not match the required output shape [30, 2]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.add(
# /Users/rafiqmazen/AMR-eval/transition-amr-parser/src/fairseq_ext/sequence_generator.py:1031: UserWarning: An output with one or more elements was resized since it had shape [32, 1], which does not match the required output shape [30, 1]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.topk(
# /Users/rafiqmazen/AMR-eval/transition-amr-parser/src/fairseq_ext/sequence_generator.py:1061: UserWarning: An output with one or more elements was resized since it had shape [32, 1], which does not match the required output shape [30, 1]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.gather(

# %%
amr_pred = parser.parse_amr_batches(loader.sentences)

# %%
from general_parser.evaluation.evaluation import eval_bottom_up, eval_top_down, eval_at_each_level, plot_smatch, plot_buckets, evaluate_AMRs

# %%
evaluate_AMRs(preds=amr_pred,gold=loader.text_amrs)

# %%
r = eval_bottom_up(amr_pred,loader.text_amrs, loader.sentences, evaluation_function="smatch")
#plot_smatch(r, "bottom up structBART")
plot_buckets(r,"bottom-up structBART over Little Price")

# %%
r = eval_top_down(amr_pred,loader.text_amrs, loader.sentences, evaluation_function="smatch")
#plot_smatch(r, "top down structBART")
plot_buckets(r,"top-down structBART over Little prince")

# %%
r = eval_at_each_level(amr_pred,loader.text_amrs, loader.sentences, evaluation_function="smatch")
#plot_smatch(r, "exact level structBART")
plot_buckets(r,"exact-level structBART over Little prince")

# %%
from amrlib.evaluate.smatch_enhanced import compute_scores, compute_smatch

# %%
from general_parser.evaluation.evaluation import eval_bottom_up

r=eval_bottom_up(amr_pred,loader.amr_texts, loader.sentences, evaluation_function="smatch")

# %%
r.dtypes

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme(style="whitegrid")



ax = sns.scatterplot(
    results, x="n_tokens", y="f1", legend="full"
)
sns.scatterplot(
    results, x="n_tokens", y="recall", legend="full"
)
sns.scatterplot(
    results, x="n_tokens", y="precision", legend="full"
)

# %%
fig,ax = plt.subplots()
plt.figure(figsize=(100,60))
p = so.Plot(r,x='n_tokens',y='f1', color='n_entries').add(so.Dot(marker='.'))
p.on(ax).show()
g.on(ax).show()

# %%
sns.scatterplot(x='n_tokens', y='value', hue='variable', 
             data=pd.melt(r[["f1","recall","precision","n_tokens"]], ['n_tokens']))

# %%
results["precision"] = [x[0] for x in results["metrics"]]
results["recall"] = [x[1] for x in results["metrics"]]
results["f1"] = [x[2] for x in results["metrics"]]

# %%
r
