# %%
from general_parser.loaders import dataset_loader
loader = dataset_loader("/Users/rafiqmazen/GR/AMR/bio/amr/full/t.txt")

# %%
from general_parser.models import transition_AMR_parser
parser = transition_AMR_parser(model_name='AMR3-joint-ontowiki-seed42')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from general_parser.models import AMR_generator
#       2 parser = AMRBART_generator()
#
# File ~/GR/notebooks/general_parser/models/__init__.py:4
#       2 from ._base_parser import AbstractParser
#       3 from ._ibm_transition_parser import transition_AMR_parser
# ----> 4 from ._AMRBART_generator import AMRBART_generator
#
# File ~/GR/notebooks/general_parser/models/_AMRBART_generator.py:2
#       1 from transformers import BartForConditionalGeneration
# ----> 2 from model_interface.tokenization_bart import AMRBartTokenizer
#       3 from transformers import pipeline
#       4 from transformers.pipelines.pt_utils import KeyDataset
#
# ModuleNotFoundError: No module named 'model_interface'

# %%
amr_pred = []
for sent in loader.sentences:
    amr_pred.append(parser.parse_amr(sent,plot=False))

# %%
amr_pred = parser.parse_amr_batches(loader.sentences)
# Out:
# Running on batch size: 256
# 6952
# decoding:   0%|          | 0/28 [00:00<?, ?it/s]/Users/rafiqmazen/GR/transition-amr-parser/src/fairseq_ext/sequence_generator_bartsv.py:1029: UserWarning: An output with one or more elements was resized since it had shape [256, 2], which does not match the required output shape [255, 2]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.add(
# /Users/rafiqmazen/GR/transition-amr-parser/src/fairseq_ext/sequence_generator_bartsv.py:1040: UserWarning: An output with one or more elements was resized since it had shape [256, 1], which does not match the required output shape [255, 1]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.topk(
# /Users/rafiqmazen/GR/transition-amr-parser/src/fairseq_ext/sequence_generator_bartsv.py:1070: UserWarning: An output with one or more elements was resized since it had shape [256, 1], which does not match the required output shape [255, 1]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.gather(
# /Users/rafiqmazen/GR/transition-amr-parser/src/fairseq_ext/sequence_generator_bartsv.py:937: UserWarning: An output with one or more elements was resized since it had shape [1], which does not match the required output shape [0]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.masked_select(
# /Users/rafiqmazen/GR/transition-amr-parser/src/fairseq_ext/sequence_generator_bartsv.py:1029: UserWarning: An output with one or more elements was resized since it had shape [255, 2], which does not match the required output shape [254, 2]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.add(
# /Users/rafiqmazen/GR/transition-amr-parser/src/fairseq_ext/sequence_generator_bartsv.py:1040: UserWarning: An output with one or more elements was resized since it had shape [255, 1], which does not match the required output shape [254, 1]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.topk(
# /Users/rafiqmazen/GR/transition-amr-parser/src/fairseq_ext/sequence_generator_bartsv.py:1070: UserWarning: An output with one or more elements was resized since it had shape [255, 1], which does not match the required output shape [254, 1]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.gather(
# /Users/rafiqmazen/GR/transition-amr-parser/src/fairseq_ext/sequence_generator_bartsv.py:1029: UserWarning: An output with one or more elements was resized since it had shape [254, 2], which does not match the required output shape [253, 2]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.add(
# /Users/rafiqmazen/GR/transition-amr-parser/src/fairseq_ext/sequence_generator_bartsv.py:1040: UserWarning: An output with one or more elements was resized since it had shape [254, 1], which does not match the required output shape [253, 1]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.topk(
# /Users/rafiqmazen/GR/transition-amr-parser/src/fairseq_ext/sequence_generator_bartsv.py:1070: UserWarning: An output with one or more elements was resized since it had shape [254, 1], which does not match the required output shape [253, 1]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.gather(
# /Users/rafiqmazen/GR/transition-amr-parser/src/fairseq_ext/sequence_generator_bartsv.py:1029: UserWarning: An output with one or more elements was resized since it had shape [253, 2], which does not match the required output shape [252, 2]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.add(
# /Users/rafiqmazen/GR/transition-amr-parser/src/fairseq_ext/sequence_generator_bartsv.py:1040: UserWarning: An output with one or more elements was resized since it had shape [253, 1], which does not match the required output shape [252, 1]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.topk(
# /Users/rafiqmazen/GR/transition-amr-parser/src/fairseq_ext/sequence_generator_bartsv.py:1070: UserWarning: An output with one or more elements was resized since it had shape [253, 1], which does not match the required output shape [252, 1]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.gather(
# /Users/rafiqmazen/GR/transition-amr-parser/src/fairseq_ext/sequence_generator_bartsv.py:1029: UserWarning: An output with one or more elements was resized since it had shape [252, 2], which does not match the required output shape [251, 2]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.add(
# /Users/rafiqmazen/GR/transition-amr-parser/src/fairseq_ext/sequence_generator_bartsv.py:1040: UserWarning: An output with one or more elements was resized since it had shape [252, 1], which does not match the required output shape [251, 1]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.topk(
# /Users/rafiqmazen/GR/transition-amr-parser/src/fairseq_ext/sequence_generator_bartsv.py:1070: UserWarning: An output with one or more elements was resized since it had shape [252, 1], which does not match the required output shape [251, 1]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.gather(
# /Users/rafiqmazen/GR/transition-amr-parser/src/fairseq_ext/sequence_generator_bartsv.py:1029: UserWarning: An output with one or more elements was resized since it had shape [251, 2], which does not match the required output shape [250, 2]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.add(
# /Users/rafiqmazen/GR/transition-amr-parser/src/fairseq_ext/sequence_generator_bartsv.py:1040: UserWarning: An output with one or more elements was resized since it had shape [251, 1], which does not match the required output shape [250, 1]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.topk(
# /Users/rafiqmazen/GR/transition-amr-parser/src/fairseq_ext/sequence_generator_bartsv.py:1070: UserWarning: An output with one or more elements was resized since it had shape [251, 1], which does not match the required output shape [250, 1]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.gather(
# /Users/rafiqmazen/GR/transition-amr-parser/src/fairseq_ext/sequence_generator_bartsv.py:1029: UserWarning: An output with one or more elements was resized since it had shape [250, 2], which does not match the required output shape [249, 2]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.add(
# /Users/rafiqmazen/GR/transition-amr-parser/src/fairseq_ext/sequence_generator_bartsv.py:1040: UserWarning: An output with one or more elements was resized since it had shape [250, 1], which does not match the required output shape [249, 1]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.topk(
# /Users/rafiqmazen/GR/transition-amr-parser/src/fairseq_ext/sequence_generator_bartsv.py:1070: UserWarning: An output with one or more elements was resized since it had shape [250, 1], which does not match the required output shape [249, 1]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.gather(
# /Users/rafiqmazen/GR/transition-amr-parser/src/fairseq_ext/sequence_generator_bartsv.py:943: UserWarning: An output with one or more elements was resized since it had shape [1], which does not match the required output shape [2]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.masked_select(
# /Users/rafiqmazen/GR/transition-amr-parser/src/fairseq_ext/sequence_generator_bartsv.py:1029: UserWarning: An output with one or more elements was resized since it had shape [249, 2], which does not match the required output shape [247, 2]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.add(
# /Users/rafiqmazen/GR/transition-amr-parser/src/fairseq_ext/sequence_generator_bartsv.py:1040: UserWarning: An output with one or more elements was resized since it had shape [249, 1], which does not match the required output shape [247, 1]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.topk(
# /Users/rafiqmazen/GR/transition-amr-parser/src/fairseq_ext/sequence_generator_bartsv.py:1070: UserWarning: An output with one or more elements was resized since it had shape [249, 1], which does not match the required output shape [247, 1]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.gather(
# /Users/rafiqmazen/GR/transition-amr-parser/src/fairseq_ext/sequence_generator_bartsv.py:937: UserWarning: An output with one or more elements was resized since it had shape [2], which does not match the required output shape [0]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.masked_select(
# /Users/rafiqmazen/GR/transition-amr-parser/src/fairseq_ext/sequence_generator_bartsv.py:1029: UserWarning: An output with one or more elements was resized since it had shape [247, 2], which does not match the required output shape [245, 2]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.add(
# /Users/rafiqmazen/GR/transition-amr-parser/src/fairseq_ext/sequence_generator_bartsv.py:1040: UserWarning: An output with one or more elements was resized since it had shape [247, 1], which does not match the required output shape [245, 1]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.topk(
# /Users/rafiqmazen/GR/transition-amr-parser/src/fairseq_ext/sequence_generator_bartsv.py:1070: UserWarning: An output with one or more elements was resized since it had shape [247, 1], which does not match the required output shape [245, 1]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.gather(
# /Users/rafiqmazen/GR/transition-amr-parser/src/fairseq_ext/sequence_generator_bartsv.py:943: UserWarning: An output with one or more elements was resized since it had shape [2], which does not match the required output shape [1]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.masked_select(
# /Users/rafiqmazen/GR/transition-amr-parser/src/fairseq_ext/sequence_generator_bartsv.py:1029: UserWarning: An output with one or more elements was resized since it had shape [245, 2], which does not match the required output shape [244, 2]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.add(
# /Users/rafiqmazen/GR/transition-amr-parser/src/fairseq_ext/sequence_generator_bartsv.py:1040: UserWarning: An output with one or more elements was resized since it had shape [245, 1], which does not match the required output shape [244, 1]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.topk(
# /Users/rafiqmazen/GR/transition-amr-parser/src/fairseq_ext/sequence_generator_bartsv.py:1070: UserWarning: An output with one or more elements was resized since it had shape [245, 1], which does not match the required output shape [244, 1]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.gather(
# /Users/rafiqmazen/GR/transition-amr-parser/src/fairseq_ext/sequence_generator_bartsv.py:937: UserWarning: An output with one or more elements was resized since it had shape [1], which does not match the required output shape [2]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.masked_select(
# /Users/rafiqmazen/GR/transition-amr-parser/src/fairseq_ext/sequence_generator_bartsv.py:1029: UserWarning: An output with one or more elements was resized since it had shape [244, 2], which does not match the required output shape [242, 2]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.add(
# /Users/rafiqmazen/GR/transition-amr-parser/src/fairseq_ext/sequence_generator_bartsv.py:1040: UserWarning: An output with one or more elements was resized since it had shape [244, 1], which does not match the required output shape [242, 1]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.topk(
# /Users/rafiqmazen/GR/transition-amr-parser/src/fairseq_ext/sequence_generator_bartsv.py:1070: UserWarning: An output with one or more elements was resized since it had shape [244, 1], which does not match the required output shape [242, 1]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.gather(
# /Users/rafiqmazen/GR/transition-amr-parser/src/fairseq_ext/sequence_generator_bartsv.py:937: UserWarning: An output with one or more elements was resized since it had shape [2], which does not match the required output shape [1]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.masked_select(
# /Users/rafiqmazen/GR/transition-amr-parser/src/fairseq_ext/sequence_generator_bartsv.py:1029: UserWarning: An output with one or more elements was resized since it had shape [242, 2], which does not match the required output shape [241, 2]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.add(
# /Users/rafiqmazen/GR/transition-amr-parser/src/fairseq_ext/sequence_generator_bartsv.py:1040: UserWarning: An output with one or more elements was resized since it had shape [242, 1], which does not match the required output shape [241, 1]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.topk(
# /Users/rafiqmazen/GR/transition-amr-parser/src/fairseq_ext/sequence_generator_bartsv.py:1070: UserWarning: An output with one or more elements was resized since it had shape [242, 1], which does not match the required output shape [241, 1]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.gather(
# /Users/rafiqmazen/GR/transition-amr-parser/src/fairseq_ext/sequence_generator_bartsv.py:1029: UserWarning: An output with one or more elements was resized since it had shape [241, 2], which does not match the required output shape [239, 2]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.add(
# /Users/rafiqmazen/GR/transition-amr-parser/src/fairseq_ext/sequence_generator_bartsv.py:1040: UserWarning: An output with one or more elements was resized since it had shape [241, 1], which does not match the required output shape [239, 1]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.topk(
# /Users/rafiqmazen/GR/transition-amr-parser/src/fairseq_ext/sequence_generator_bartsv.py:1070: UserWarning: An output with one or more elements was resized since it had shape [241, 1], which does not match the required output shape [239, 1]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.gather(
# /Users/rafiqmazen/GR/transition-amr-parser/src/fairseq_ext/sequence_generator_bartsv.py:1029: UserWarning: An output with one or more elements was resized since it had shape [239, 2], which does not match the required output shape [237, 2]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.add(
# /Users/rafiqmazen/GR/transition-amr-parser/src/fairseq_ext/sequence_generator_bartsv.py:1040: UserWarning: An output with one or more elements was resized since it had shape [239, 1], which does not match the required output shape [237, 1]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.topk(
# /Users/rafiqmazen/GR/transition-amr-parser/src/fairseq_ext/sequence_generator_bartsv.py:1070: UserWarning: An output with one or more elements was resized since it had shape [239, 1], which does not match the required output shape [237, 1]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.gather(
# /Users/rafiqmazen/GR/transition-amr-parser/src/fairseq_ext/sequence_generator_bartsv.py:937: UserWarning: An output with one or more elements was resized since it had shape [2], which does not match the required output shape [4]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.masked_select(
# /Users/rafiqmazen/GR/transition-amr-parser/src/fairseq_ext/sequence_generator_bartsv.py:943: UserWarning: An output with one or more elements was resized since it had shape [2], which does not match the required output shape [4]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.masked_select(
# /Users/rafiqmazen/GR/transition-amr-parser/src/fairseq_ext/sequence_generator_bartsv.py:1029: UserWarning: An output with one or more elements was resized since it had shape [237, 2], which does not match the required output shape [233, 2]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.add(
# /Users/rafiqmazen/GR/transition-amr-parser/src/fairseq_ext/sequence_generator_bartsv.py:1040: UserWarning: An output with one or more elements was resized since it had shape [237, 1], which does not match the required output shape [233, 1]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.topk(
# /Users/rafiqmazen/GR/transition-amr-parser/src/fairseq_ext/sequence_generator_bartsv.py:1070: UserWarning: An output with one or more elements was resized since it had shape [237, 1], which does not match the required output shape [233, 1]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.gather(
# /Users/rafiqmazen/GR/transition-amr-parser/src/fairseq_ext/sequence_generator_bartsv.py:937: UserWarning: An output with one or more elements was resized since it had shape [4], which does not match the required output shape [2]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.masked_select(
# /Users/rafiqmazen/GR/transition-amr-parser/src/fairseq_ext/sequence_generator_bartsv.py:943: UserWarning: An output with one or more elements was resized since it had shape [4], which does not match the required output shape [2]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.masked_select(
# /Users/rafiqmazen/GR/transition-amr-parser/src/fairseq_ext/sequence_generator_bartsv.py:1029: UserWarning: An output with one or more elements was resized since it had shape [233, 2], which does not match the required output shape [231, 2]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.add(
# /Users/rafiqmazen/GR/transition-amr-parser/src/fairseq_ext/sequence_generator_bartsv.py:1040: UserWarning: An output with one or more elements was resized since it had shape [233, 1], which does not match the required output shape [231, 1]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.topk(
# /Users/rafiqmazen/GR/transition-amr-parser/src/fairseq_ext/sequence_generator_bartsv.py:1070: UserWarning: An output with one or more elements was resized since it had shape [233, 1], which does not match the required output shape [231, 1]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.gather(
# /Users/rafiqmazen/GR/transition-amr-parser/src/fairseq_ext/sequence_generator_bartsv.py:1029: UserWarning: An output with one or more elements was resized since it had shape [231, 2], which does not match the required output shape [230, 2]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.add(
# /Users/rafiqmazen/GR/transition-amr-parser/src/fairseq_ext/sequence_generator_bartsv.py:1040: UserWarning: An output with one or more elements was resized since it had shape [231, 1], which does not match the required output shape [230, 1]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.topk(
# /Users/rafiqmazen/GR/transition-amr-parser/src/fairseq_ext/sequence_generator_bartsv.py:1070: UserWarning: An output with one or more elements was resized since it had shape [231, 1], which does not match the required output shape [230, 1]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.gather(
# /Users/rafiqmazen/GR/transition-amr-parser/src/fairseq_ext/sequence_generator_bartsv.py:937: UserWarning: An output with one or more elements was resized since it had shape [1], which does not match the required output shape [4]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.masked_select(
# /Users/rafiqmazen/GR/transition-amr-parser/src/fairseq_ext/sequence_generator_bartsv.py:943: UserWarning: An output with one or more elements was resized since it had shape [1], which does not match the required output shape [4]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.masked_select(
# /Users/rafiqmazen/GR/transition-amr-parser/src/fairseq_ext/sequence_generator_bartsv.py:1029: UserWarning: An output with one or more elements was resized since it had shape [230, 2], which does not match the required output shape [226, 2]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.add(
# /Users/rafiqmazen/GR/transition-amr-parser/src/fairseq_ext/sequence_generator_bartsv.py:1040: UserWarning: An output with one or more elements was resized since it had shape [230, 1], which does not match the required output shape [226, 1]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.topk(
# /Users/rafiqmazen/GR/transition-amr-parser/src/fairseq_ext/sequence_generator_bartsv.py:1070: UserWarning: An output with one or more elements was resized since it had shape [230, 1], which does not match the required output shape [226, 1]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.gather(
# /Users/rafiqmazen/GR/transition-amr-parser/src/fairseq_ext/sequence_generator_bartsv.py:1029: UserWarning: An output with one or more elements was resized since it had shape [226, 2], which does not match the required output shape [224, 2]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.add(
# /Users/rafiqmazen/GR/transition-amr-parser/src/fairseq_ext/sequence_generator_bartsv.py:1040: UserWarning: An output with one or more elements was resized since it had shape [226, 1], which does not match the required output shape [224, 1]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.topk(
# /Users/rafiqmazen/GR/transition-amr-parser/src/fairseq_ext/sequence_generator_bartsv.py:1070: UserWarning: An output with one or more elements was resized since it had shape [226, 1], which does not match the required output shape [224, 1]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.gather(
# /Users/rafiqmazen/GR/transition-amr-parser/src/fairseq_ext/sequence_generator_bartsv.py:943: UserWarning: An output with one or more elements was resized since it had shape [2], which does not match the required output shape [3]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.masked_select(
# /Users/rafiqmazen/GR/transition-amr-parser/src/fairseq_ext/sequence_generator_bartsv.py:1029: UserWarning: An output with one or more elements was resized since it had shape [224, 2], which does not match the required output shape [221, 2]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.add(
# /Users/rafiqmazen/GR/transition-amr-parser/src/fairseq_ext/sequence_generator_bartsv.py:1040: UserWarning: An output with one or more elements was resized since it had shape [224, 1], which does not match the required output shape [221, 1]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.topk(
# /Users/rafiqmazen/GR/transition-amr-parser/src/fairseq_ext/sequence_generator_bartsv.py:1070: UserWarning: An output with one or more elements was resized since it had shape [224, 1], which does not match the required output shape [221, 1]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.gather(
# /Users/rafiqmazen/GR/transition-amr-parser/src/fairseq_ext/sequence_generator_bartsv.py:937: UserWarning: An output with one or more elements was resized since it had shape [3], which does not match the required output shape [1]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.masked_select(
# /Users/rafiqmazen/GR/transition-amr-parser/src/fairseq_ext/sequence_generator_bartsv.py:943: UserWarning: An output with one or more elements was resized since it had shape [3], which does not match the required output shape [1]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.masked_select(
# /Users/rafiqmazen/GR/transition-amr-parser/src/fairseq_ext/sequence_generator_bartsv.py:1029: UserWarning: An output with one or more elements was resized since it had shape [221, 2], which does not match the required output shape [220, 2]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.add(
# /Users/rafiqmazen/GR/transition-amr-parser/src/fairseq_ext/sequence_generator_bartsv.py:1040: UserWarning: An output with one or more elements was resized since it had shape [221, 1], which does not match the required output shape [220, 1]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.topk(
# /Users/rafiqmazen/GR/transition-amr-parser/src/fairseq_ext/sequence_generator_bartsv.py:1070: UserWarning: An output with one or more elements was resized since it had shape [221, 1], which does not match the required output shape [220, 1]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.gather(
# /Users/rafiqmazen/GR/transition-amr-parser/src/fairseq_ext/sequence_generator_bartsv.py:1029: UserWarning: An output with one or more elements was resized since it had shape [220, 2], which does not match the required output shape [219, 2]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.add(
# /Users/rafiqmazen/GR/transition-amr-parser/src/fairseq_ext/sequence_generator_bartsv.py:1040: UserWarning: An output with one or more elements was resized since it had shape [220, 1], which does not match the required output shape [219, 1]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.topk(
# /Users/rafiqmazen/GR/transition-amr-parser/src/fairseq_ext/sequence_generator_bartsv.py:1070: UserWarning: An output with one or more elements was resized since it had shape [220, 1], which does not match the required output shape [219, 1]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.gather(
# /Users/rafiqmazen/GR/transition-amr-parser/src/fairseq_ext/sequence_generator_bartsv.py:1029: UserWarning: An output with one or more elements was resized since it had shape [219, 2], which does not match the required output shape [217, 2]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.add(
# ...
#   torch.topk(
# /Users/rafiqmazen/GR/transition-amr-parser/src/fairseq_ext/sequence_generator_bartsv.py:1070: UserWarning: An output with one or more elements was resized since it had shape [157, 1], which does not match the required output shape [155, 1]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.gather(
# /Users/rafiqmazen/GR/transition-amr-parser/src/fairseq_ext/sequence_generator_bartsv.py:1029: UserWarning: An output with one or more elements was resized since it had shape [136, 2], which does not match the required output shape [131, 2]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.add(
# /Users/rafiqmazen/GR/transition-amr-parser/src/fairseq_ext/sequence_generator_bartsv.py:1040: UserWarning: An output with one or more elements was resized since it had shape [136, 1], which does not match the required output shape [131, 1]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.topk(
# /Users/rafiqmazen/GR/transition-amr-parser/src/fairseq_ext/sequence_generator_bartsv.py:1070: UserWarning: An output with one or more elements was resized since it had shape [136, 1], which does not match the required output shape [131, 1]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.gather(
# /Users/rafiqmazen/GR/transition-amr-parser/src/fairseq_ext/sequence_generator_bartsv.py:1029: UserWarning: An output with one or more elements was resized since it had shape [131, 2], which does not match the required output shape [128, 2]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.add(
# /Users/rafiqmazen/GR/transition-amr-parser/src/fairseq_ext/sequence_generator_bartsv.py:1040: UserWarning: An output with one or more elements was resized since it had shape [131, 1], which does not match the required output shape [128, 1]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.topk(
# /Users/rafiqmazen/GR/transition-amr-parser/src/fairseq_ext/sequence_generator_bartsv.py:1070: UserWarning: An output with one or more elements was resized since it had shape [131, 1], which does not match the required output shape [128, 1]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.gather(
# /Users/rafiqmazen/GR/transition-amr-parser/src/fairseq_ext/sequence_generator_bartsv.py:1029: UserWarning: An output with one or more elements was resized since it had shape [128, 2], which does not match the required output shape [127, 2]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.add(
# /Users/rafiqmazen/GR/transition-amr-parser/src/fairseq_ext/sequence_generator_bartsv.py:1040: UserWarning: An output with one or more elements was resized since it had shape [128, 1], which does not match the required output shape [127, 1]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.topk(
# /Users/rafiqmazen/GR/transition-amr-parser/src/fairseq_ext/sequence_generator_bartsv.py:1070: UserWarning: An output with one or more elements was resized since it had shape [128, 1], which does not match the required output shape [127, 1]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.gather(
# /Users/rafiqmazen/GR/transition-amr-parser/src/fairseq_ext/sequence_generator_bartsv.py:1029: UserWarning: An output with one or more elements was resized since it had shape [103, 2], which does not match the required output shape [95, 2]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.add(
# /Users/rafiqmazen/GR/transition-amr-parser/src/fairseq_ext/sequence_generator_bartsv.py:1040: UserWarning: An output with one or more elements was resized since it had shape [103, 1], which does not match the required output shape [95, 1]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.topk(
# /Users/rafiqmazen/GR/transition-amr-parser/src/fairseq_ext/sequence_generator_bartsv.py:1070: UserWarning: An output with one or more elements was resized since it had shape [103, 1], which does not match the required output shape [95, 1]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.gather(
# /Users/rafiqmazen/GR/transition-amr-parser/src/fairseq_ext/sequence_generator_bartsv.py:1029: UserWarning: An output with one or more elements was resized since it had shape [87, 2], which does not match the required output shape [84, 2]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.add(
# /Users/rafiqmazen/GR/transition-amr-parser/src/fairseq_ext/sequence_generator_bartsv.py:1040: UserWarning: An output with one or more elements was resized since it had shape [87, 1], which does not match the required output shape [84, 1]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.topk(
# /Users/rafiqmazen/GR/transition-amr-parser/src/fairseq_ext/sequence_generator_bartsv.py:1070: UserWarning: An output with one or more elements was resized since it had shape [87, 1], which does not match the required output shape [84, 1]. This behavior is deprecated, and in a future PyTorch release outputs will not be resized unless they have zero elements. You can explicitly reuse an out tensor t by resizing it, inplace, to zero elements with t.resize_(0). (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/aten/src/ATen/native/Resize.cpp:24.)
#   torch.gather(
# decoding: 100%|██████████| 28/28 [2:14:54<00:00, 289.09s/it]
# WARNING: disconnected graphs
# WARNING: disconnected graphs
# WARNING: disconnected graphs
# WARNING: disconnected graphs
# WARNING: disconnected graphs
# WARNING: disconnected graphs
# WARNING: disconnected graphs
# WARNING: disconnected graphs
# WARNING: disconnected graphs
# WARNING: disconnected graphs
# WARNING: disconnected graphs
# WARNING: disconnected graphs
# WARNING: disconnected graphs
# WARNING: disconnected graphs
# WARNING: disconnected graphs
# WARNING: disconnected graphs
# WARNING: disconnected graphs
# WARNING: disconnected graphs
# WARNING: disconnected graphs
# WARNING: disconnected graphs
# WARNING: disconnected graphs
# WARNING: disconnected graphs
# WARNING: disconnected graphs
# WARNING: disconnected graphs
# WARNING: disconnected graphs
# WARNING: disconnected graphs
# WARNING: disconnected graphs
# WARNING: disconnected graphs
# WARNING: disconnected graphs
# WARNING: disconnected graphs
# WARNING: disconnected graphs
# WARNING: disconnected graphs
# WARNING: disconnected graphs
# WARNING: disconnected graphs
# WARNING: disconnected graphs
# WARNING: disconnected graphs
# WARNING: disconnected graphs
# WARNING: disconnected graphs
# WARNING: disconnected graphs
# WARNING: disconnected graphs
# WARNING: disconnected graphs
# WARNING: disconnected graphs
# WARNING: disconnected graphs
# WARNING: disconnected graphs
# WARNING: disconnected graphs
# WARNING: disconnected graphs
# WARNING: disconnected graphs
# WARNING: disconnected graphs
# WARNING: disconnected graphs
# WARNING: disconnected graphs
# WARNING: disconnected graphs
# WARNING: missing root
# WARNING: disconnected graphs
# WARNING: disconnected graphs
# WARNING: disconnected graphs
# WARNING: disconnected graphs
# WARNING: disconnected graphs
# WARNING: disconnected graphs
# WARNING: disconnected graphs
# WARNING: disconnected graphs
# WARNING: disconnected graphs
# WARNING: disconnected graphs
# WARNING: disconnected graphs
# WARNING: disconnected graphs
# WARNING: disconnected graphs
# WARNING: disconnected graphs
# WARNING: disconnected graphs
# WARNING: disconnected graphs
# WARNING: disconnected graphs
# WARNING: disconnected graphs
# WARNING: disconnected graphs
# WARNING: disconnected graphs
# WARNING: disconnected graphs
# WARNING: disconnected graphs
# WARNING: disconnected graphs
# WARNING: disconnected graphs
# WARNING: disconnected graphs
# WARNING: disconnected graphs
# WARNING: disconnected graphs
# WARNING: disconnected graphs
# WARNING: disconnected graphs
# WARNING: disconnected graphs
# WARNING: disconnected graphs
# WARNING: disconnected graphs
# WARNING: disconnected graphs
# WARNING: disconnected graphs
# WARNING: disconnected graphs
# WARNING: disconnected graphs
# WARNING: disconnected graphs
# WARNING: disconnected graphs
# WARNING: disconnected graphs
# WARNING: disconnected graphs
# WARNING: disconnected graphs
# WARNING: disconnected graphs
# WARNING: disconnected graphs
# WARNING: disconnected graphs
# WARNING: disconnected graphs
# WARNING: disconnected graphs
# WARNING: disconnected graphs
# WARNING: disconnected graphs
# WARNING: disconnected graphs
# WARNING: disconnected graphs
# WARNING: disconnected graphs
# WARNING: disconnected graphs
# WARNING: disconnected graphs
# WARNING: disconnected graphs
# WARNING: disconnected graphs
# WARNING: disconnected graphs
# WARNING: disconnected graphs
# WARNING: disconnected graphs
# WARNING: disconnected graphs
# WARNING: disconnected graphs
# WARNING: disconnected graphs
# WARNING: disconnected graphs
# WARNING: disconnected graphs
# WARNING: disconnected graphs
# WARNING: disconnected graphs
# WARNING: disconnected graphs
# WARNING: disconnected graphs
# WARNING: disconnected graphs
# WARNING: disconnected graphs
# WARNING: disconnected graphs
# WARNING: disconnected graphs
# WARNING: disconnected graphs
# WARNING: disconnected graphs
# WARNING: disconnected graphs
# WARNING: disconnected graphs
# WARNING: disconnected graphs
# WARNING: disconnected graphs
# WARNING: disconnected graphs
# WARNING: disconnected graphs
# WARNING: disconnected graphs
# WARNING: disconnected graphs
# WARNING: disconnected graphs
# WARNING: disconnected graphs
# WARNING: disconnected graphs
# WARNING: missing root
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 amr_pred = parser.parse_amr_batches(loader.sentences)
#
# File ~/GR/notebooks/general_parser/models/_ibm_transition_parser.py:25, in transition_AMR_parser.parse_amr_batches(self, sentences)
#      23      tokens, _ = self.parser.tokenize(sent)
#      24      tokens_list.append(tokens)
# ---> 25 _ , machines = self.parser.parse_sentences(tokens_list, batch_size=256)
#      26 for machine in machines:
#      27     amrs.append(machine.get_amr().to_penman(jamr=False, isi=False)  )
#
# File ~/GR/transition-amr-parser/src/transition_amr_parser/parse.py:1066, in AMRParser.parse_sentences(self, batch, batch_size, roberta_batch_size, gold_amrs, force_actions, beam, jamr, no_isi, unicode_normalize)
#    1062 machine_nbest = completed_machines[i]
#    1064 if len(machine_nbest) == 1:
#    1065     annotations.append(
# -> 1066         machine_nbest[0].get_annotation(jamr=jamr, no_isi=no_isi)
#    1067     )
#    1068     machines.append(machine_nbest[0])
#    1069 else:
#
# File ~/GR/transition-amr-parser/src/transition_amr_parser/amr_machine.py:1307, in AMRStateMachine.get_annotation(self, node_map, jamr, no_isi)
#    1304     return self.align_tracker.add_alignments_to_penman(self)
#    1306 else:
# -> 1307     amr = self.get_amr(node_map=node_map)
#    1308     return amr.to_penman(jamr=jamr, isi=not no_isi)
#
# File ~/GR/transition-amr-parser/src/transition_amr_parser/amr_machine.py:1287, in AMRStateMachine.get_amr(self, node_map)
#    1282 tokens, nodes, edges, root, alignments = create_valid_amr(
#    1283     self.tokens, self.nodes, self.edges, self.root, self.alignments
#    1284 )
#    1286 # create an AMR class
# -> 1287 amr = AMR(tokens, nodes, edges, root, alignments=alignments)
#    1289 # use valid node names
#    1290 if node_map is None:
#
# File ~/GR/transition-amr-parser/src/transition_amr_parser/amr.py:713, in AMR.__init__(self, tokens, nodes, edges, root, penman, alignments, sentence, id, sentence_ends)
#     711 self.root = root
#     712 self.roots = []
# --> 713 if self.nodes[self.root] == 'document':
#     714     for (s, rel, t) in self.edges:
#     715         if s == self.root and rel.startswith(':snt'):
#
# KeyError: None

# %%
amr_pred = parser.parse_amr_batches(loader.sentences)

# %%
from general_parser.evaluation.evaluation import eval_bottom_up, eval_top_down, eval_at_each_level, plot_smatch, plot_buckets, evaluate_AMRs

# %%
evaluate_AMRs(preds=amr_pred,gold=loader.text_amrs)

# %%
r = eval_bottom_up(amr_pred,loader.text_amrs, loader.sentences, evaluation_function="smatch")
plot_smatch(r, "bottom up structBART")
plot_buckets(r,"bottom up structBART")

# %%
r = eval_top_down(amr_pred,loader.text_amrs, loader.sentences, evaluation_function="smatch")
plot_smatch(r, "top down structBART")
plot_buckets(r,"top down structBART")

# %%
r = eval_at_each_level(amr_pred,loader.text_amrs, loader.sentences, evaluation_function="smatch")
plot_smatch(r, "exact level structBART")
plot_buckets(r,"exact level structBART")

# %%
from amrlib.evaluate.smatch_enhanced import compute_scores, compute_smatch

# %%
from general_parser.evaluation.evaluation import eval_bottom_up

r=eval_bottom_up(amr_pred,loader.amr_texts, loader.sentences, evaluation_function="smatch")

# %%
r.dtypes

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme(style="whitegrid")



ax = sns.scatterplot(
    results, x="n_tokens", y="f1", legend="full"
)
sns.scatterplot(
    results, x="n_tokens", y="recall", legend="full"
)
sns.scatterplot(
    results, x="n_tokens", y="precision", legend="full"
)

# %%
fig,ax = plt.subplots()
plt.figure(figsize=(100,60))
p = so.Plot(r,x='n_tokens',y='f1', color='n_entries').add(so.Dot(marker='.'))
p.on(ax).show()
g.on(ax).show()

# %%
sns.scatterplot(x='n_tokens', y='value', hue='variable', 
             data=pd.melt(r[["f1","recall","precision","n_tokens"]], ['n_tokens']))

# %%
results["precision"] = [x[0] for x in results["metrics"]]
results["recall"] = [x[1] for x in results["metrics"]]
results["f1"] = [x[2] for x in results["metrics"]]

# %%
r
